# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gemma3:1b")

# %%
res = llm.invoke("What is the captial of India ?")

# %%
res.content
# Out:
# 'The capital of India is **New Delhi**. \n\nIt’s located in the northeast of the country. 😊'
