# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
google_llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
res = llm.invoke("What is GenAI?")

# %%
ans = google_llm.invoke("What is GenAI?")

# %%
print(res.content)
# Out:
# ### GenAI in a nutshell
#
# **GenAI** (short for *Generative Artificial Intelligence*) refers to AI systems that can **create new content**—text, images, music, code, and more—rather than just classify or predict existing data. Think of it as a “creative partner” that can draft emails, paint a portrait, compose a song, or write a short story on the spot.
#
# ---
#
# ## How it works (high‑level)
#
# | Step | What happens | Key tech |
# |------|--------------|----------|
# | **1. Data ingestion** | The model is fed massive amounts of text, images, or other data. | Web crawls, books, code repositories, image datasets, etc. |
# | **2. Training** | The model learns patterns, syntax, semantics, and style by predicting the next token (word, pixel, note). | Transformer architecture (self‑attention), gradient descent, large‑scale distributed computing. |
# | **3. Fine‑tuning (optional)** | The base model is further trained on a narrower domain or style to improve relevance. | Supervised fine‑tuning, reinforcement learning from human feedback (RLHF). |
# | **4. Generation** | Given a prompt, the model samples from its learned distribution to produce new content. | Sampling strategies (greedy, top‑k, nucleus), temperature control. |
#
# > **Why it matters** – The transformer architecture lets the model capture long‑range dependencies and subtle stylistic nuances, making its outputs surprisingly coherent and “creative.”
#
# ---
#
# ## What it can do
#
# | Domain | Typical GenAI use cases |
# |--------|------------------------|
# | **Text** | Chatbots, auto‑completion, summarization, translation, content drafting, coding assistants (e.g., GitHub Copilot). |
# | **Images** | Photo‑style transfer, image up‑scaling, concept art, realistic portraits (DALL‑E, Midjourney, Stable Diffusion). |
# | **Audio** | Voice cloning, music composition, sound effect generation. |
# | **Video** | Frame interpolation, style transfer, text‑to‑video generation. |
# | **Code** | Auto‑completion, bug detection, automated documentation. |
#
# ---
#
# ## Key differences from other AI
#
# | Type | Focus | Example |
# |------|-------|---------|
# | **Discriminative AI** | Predicts labels or outcomes from inputs (e.g., image classification). | ResNet, BERT for classification. |
# | **Generative AI** | Produces new data that could plausibly belong to the same distribution. | GPT‑4, Stable Diffusion. |
# | **Hybrid** | Combines both—e.g., a model that can classify *and* generate. | GPT‑4 can both answer questions and write code. |
#
# ---
#
# ## Benefits
#
# 1. **Productivity boost** – Drafts, code snippets, designs, and ideas at a fraction of the time.
# 2. **Accessibility** – Low‑skill users can produce high‑quality content (e.g., marketing copy, website copy).
# 3. **Innovation** – Enables new creative workflows (e.g., AI‑co‑created art, music, or storytelling).
# 4. **Personalization** – Tailors content to user preferences in real time.
#
# ---
#
# ## Challenges & Risks
#
# | Risk | Why it matters | Mitigation strategies |
# |------|----------------|-----------------------|
# | **Bias & fairness** | Models learn biases present in training data. | Diverse training sets, bias auditing, post‑generation filtering. |
# | **Hallucinations** | The model may produce plausible but false information. | Fact‑checking pipelines, user prompts to ask for citations. |
# | **Copyright & IP** | Generated content may infringe existing works. | Copyright‑aware training, watermarking, licensing frameworks. |
# | **Security** | Potential misuse (deepfakes, phishing). | Detection tools, usage policies, regulatory oversight. |
# | **Privacy** | Models may inadvertently reveal private data. | Differential privacy, data sanitization. |
#
# ---
#
# ## Practical take‑aways
#
# - **Start small**: Use a pre‑trained model (e.g., GPT‑4 or Stable Diffusion) via an API to test a single use case.
# - **Prompt engineering**: The quality of the output is heavily influenced by how you phrase the prompt.
# - **Human‑in‑the‑loop**: Combine GenAI output with human review for best results.
# - **Stay ethical**: Follow guidelines (OpenAI’s use‑case policy, EU AI Act, etc.) and be transparent about AI involvement.
#
# ---
#
# ### Bottom line
#
# GenAI is a powerful, rapidly evolving technology that turns data into *creative* output. It’s not just about “seeing” or “predicting”; it’s about *making*—from words and code to pictures and melodies—often with a level of nuance that feels surprisingly human. As it matures, the key will be to harness its benefits while actively managing its ethical, legal, and societal impacts.

# %%
print(ans.content)
# Out:
# **GenAI** stands for **Generative Artificial Intelligence**.
#
# It's a type of artificial intelligence that can **create new, original content** rather than just analyzing or classifying existing data. Unlike traditional AI that might identify a cat in a picture, GenAI can *generate* a picture of a cat that has never existed before, based on its understanding of what a cat looks like.
#
# ### What "Generative" Means
#
# The "generative" aspect is key. GenAI models are trained on massive datasets (e.g., billions of text documents, millions of images, hours of audio). During this training, they learn the underlying patterns, structures, styles, and relationships within that data. Once trained, they can use this learned knowledge to produce novel outputs that mimic the characteristics of their training data but are entirely new.
#
# ### How GenAI Works (Simplified)
#
# 1.  **Training:** A GenAI model is fed vast amounts of data (text, images, audio, video, code, etc.).
# 2.  **Pattern Recognition:** The model learns the statistical probabilities and intricate patterns within this data – how words follow each other, how pixels form objects, how musical notes create melodies.
# 3.  **Generation:** When given a **prompt** (an instruction or input, often in natural language), the model applies these learned patterns to "generate" new content that fits the prompt and is consistent with the style and information it has learned.
#
# ### Key Capabilities and Types of Output
#
# GenAI is incredibly versatile and can generate a wide range of content:
#
# *   **Text:** Writing articles, stories, poems, emails, summaries, code, scripts, translations, answering questions (e.g., ChatGPT, Google Gemini).
# *   **Images:** Creating artwork, photorealistic images, logos, designs from text descriptions (e.g., DALL-E, Midjourney, Stable Diffusion).
# *   **Audio:** Generating music, voiceovers, sound effects, or even entire songs.
# *   **Video:** Producing short clips, animations, or even full videos from text or image prompts.
# *   **Code:** Writing, debugging, and explaining programming code in various languages (e.g., GitHub Copilot).
# *   **3D Models:** Creating 3D objects and environments.
#
# ### Why it's Important
#
# GenAI represents a significant leap in AI capabilities because it moves beyond analysis to active creation. It has the potential to:
#
# *   **Democratize Creativity:** Allow anyone to generate high-quality content without specialized skills.
# *   **Automate Tasks:** Streamline content creation, design, and coding workflows.
# *   **Accelerate Innovation:** Help researchers and developers rapidly prototype ideas.
# *   **Personalize Experiences:** Create highly customized content for individuals.
# *   **Enable New Forms of Interaction:** Lead to more natural and intuitive human-computer interfaces.
#
# ### Challenges and Considerations
#
# While powerful, GenAI also comes with challenges:
#
# *   **Bias:** Models can inherit and amplify biases present in their training data.
# *   **Hallucinations:** They can generate plausible-sounding but incorrect or nonsensical information.
# *   **Ethical Concerns:** Issues around copyright, deepfakes, misinformation, and job displacement.
# *   **Environmental Impact:** Training large models requires significant computational power and energy.
# *   **Control and Safety:** Ensuring the outputs are aligned with human values and intentions.
#
# In essence, GenAI is about AI that doesn't just understand the world, but can actively contribute to it by bringing new ideas and creations into existence.
