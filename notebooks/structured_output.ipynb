# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
text = "Hi, My name is Akanshu Mittal" \
    "Email is akanshu132mittal@gmail.com and My age is 21."

# %%
res = llm.invoke(f"Please give me only name, email and age from the given text: {text}")

# %%
res.content
# Out:
# 'Name: Akanshu Mittal\nEmail: akanshu132mittal@gmail.com\nAge: 21'

# %%
print(res.content)
# Out:
# Name: Akanshu Mittal
# Email: akanshu132mittal@gmail.com
# Age: 21

# %% [markdown]
# ## Structured Output

# %%
from pydantic import BaseModel, Field

class ResponseStructure(BaseModel):
    name: str  = Field(description="Complete Name")
    email: str = Field(description="Email Address")
    age: int = Field(description="Age")

# %%
str_out = llm.with_structured_output(ResponseStructure)

# %%
res = str_out.invoke(f"Please give me only name, email and age from the given text: {text}")

# %%
res.name
# Out:
# 'Akanshu Mittal'

# %%
# Dictionary Output 
res.model_dump()
# Out:
# {'name': 'Akanshu Mittal', 'email': 'akanshu132mittal@gmail.com', 'age': 21}

# %%
from typing import List

class Movies(BaseModel):
    title: str = Field(description="Movie Title")
    year: int = Field(description="Movie Released")
    
class AllMovies(BaseModel):
    movies: List[Movies]

# %%
movies_out = llm.with_structured_output(AllMovies)

# %%
res = movies_out.invoke("Give me three latest movie name")

# %%
res
# Out:
# AllMovies(movies=[Movies(title='Dune: Part Two', year=2024), Movies(title='Kingdom of the Planet of the Apes', year=2024), Movies(title='Furiosa: A Mad Max Saga', year=2024)])
