# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

# %%
@tool
def add_numbers(a: int, b: int):
    """
    It will return the sum of two numbers
    
    Args:
    a : Number One
    b : Number Two
    """
    return a + b

# %%
add_numbers.invoke({"a": 5, "b": 4})
# Out:
# 9
