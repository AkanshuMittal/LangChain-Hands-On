# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
search.run("Where AI Impact Summit 2026 was being held ?")
# Out:
# "The AI Impact Summit was an international summit on artificial intelligence (AI) held in New Delhi from 16 to 20 February 2026. It followed the AI ... The India–AI Impact Summit 2026, announced by Hon'ble Prime Minister Narendra Modi at the France AI Action Summit and scheduled for February 19–20 in New Delhi, ... India AI Impact Summit 2026\u200b: ODET Side Events 18–20 February 2026 Bharat Mandapam · New Delhi · India Livestream Link Links to individual session ... The India AI Impact Summit 2026 is a flagship global gathering hosted by the Government of India under the IndiaAI Mission, in collaboration with the ... India is hosting the AI Impact Summit 2026 in New Delhi from February 16 to February 20, drawing heads of states, policymakers, ... Prime Minister Narendra Modi will convene the India - AI Impact Summit on 19 – 20 February 2026, the latest in a series of global AI summits that have been held ... The India AI Impact Summit 2026 brings together global leaders to shape how artificial intelligence can drive inclusive growth, strengthen public services, ... The leading solutions get showcased at the India - AI Impact Summit to be held in New Delhi, India in February 2026. The India AI Impact Summit 2026, held from 16–21 February 2026, marked a significant milestone in the global artificial intelligence landscape. Prime Minister Shri Narendra Modi will visit and inaugurate the India AI Impact Summit 2026 on 19 February at Bharat Mandapam, New Delhi. Prior ..."
