# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

# %%
openai_llm = ChatOpenAI(model="gpt-4", streaming=True)

# %%
question = "Can you explain what is GenAI ?"

# %%
response = openai_llm.stream(question)

# %%
print(response)
# Out:
# <generator object BaseChatModel.stream at 0x00000214A3395620>

# %%
for chunk in response:
    print(chunk.content, end="")
# Out:
# GenAI, short for General Artificial Intelligence, refers to a type of artificial intelligence that is capable of understanding, learning, and applying knowledge across a wide variety of tasks. Unlike narrow AI, which is designed for specific tasks (e.g., Amazon's Alexa), GenAI has an autonomous system that can independently build a comprehension of the world by acquiring information, adjusting to new inputs, and displaying more intuitive responses.
#
# In other words, general artificial intelligence implies AI that can perform any intellectual task that a human being can do. It involves machines being able to handle tasks that would typically require human intelligence, like understanding natural language, recognizing complex patterns, solving problems and making decisions.

# %%
from langchain_groq import ChatGroq

# %%
groq_llm = ChatGroq(model="openai/gpt-oss-20b", streaming=True)

# %%
answer = groq_llm.stream(question)

# %%
for chunk in answer:
    print(chunk.content, end="")
# Out:
# **GenAI – Generative Artificial Intelligence**
#
# > *“Generative AI” (or *GenAI*) refers to a class of machine‑learning models that can **create new data**—text, images, audio, video, code, and more—rather than just *recognize* or *classify* existing data.
#
# ---
#
# ## 1. What GenAI actually does
#
# | Domain | Example of what it can generate | Typical use‑case |
# |--------|--------------------------------|------------------|
# | **Text** | Stories, essays, emails, code, legal contracts | Chatbots, content creation, programming assistants |
# | **Images** | Photorealistic photos, artwork, design mock‑ups | Graphic design, advertising, product visualization |
# | **Audio** | Music, voice‑overs, speech synthesis | Soundtracks, voice assistants, dubbing |
# | **Video** | Short clips, animations, deepfakes | Marketing, entertainment, training simulations |
# | **Multimodal** | Text‑to‑image, image‑to‑text, video‑to‑text | Captioning, accessibility, content moderation |
#
# ...
